# %% [markdown]
# Matplotlib is a popular data visualization library in Python used to create basic as well as advanced plots. It is built on top of NumPy arrays and integrates directly with Pandas dataframes. Some of the key features of Matplotlib include a simple to use interface, the ability to create various types of plots including line, scatter, bar, and histogram plots, and the ability to customize these plots to fit your needs.
#
# A Matplotlib flow
# 1. create data
# 2. Create plot
# 3. plot data (axes on figure)
# 4. customize plot
# 5. save/share the plot
#
# There are two ways to plot data in Matplotlib - using the pyplot interface and the object-oriented interface. The pyplot interface is a collection of functions that make Matplotlib work like MATLAB, while the object-oriented interface provides more control and flexibility over the plot creation process.
#
# When plotting data from NumPy arrays, you can use the plot function to create line plots or the scatter function to create scatter plots. When plotting data from Pandas dataframes, you can simply call the plot method on the dataframe.
#
# Customizing plots in Matplotlib can involve changing plot titles, axis labels, color schemes, and plot styles. There are various customization options available in Matplotlib to help you create the perfect plot.
#
# Once you have created your plot, you can save it using the savefig function and share it with others.

# %% [markdown]
# MATPLOTLIB Documentation :
#
# 1. https://matplotlib.org/3.1.1/contents.html
# 2. https://matplotlib.org/stable/users/index.html

# %%
# Import matplotlib and setup the figures to display within the notebook
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Create a simple plot, without the semi-colon
plt.plot()
# Out:
# []

# %%
# With the semi-colon
plt.plot();

# %%
    # You could use plt.show() if you want
plt.plot()
plt.show()

# %%
# Let's add some data
plt.plot([1, 2, 3, 4])
plt.show()

# %%
x = [10,20,33,79]
y = [11,22,33,44]
plt.plot(x,y)
plt.show()

# %%
# Creating a plot with the OO verison, confusing way first
fig = plt.figure()
ax = fig.add_subplot()
plt.show()

#Create a figure and axes using the add_subplot() method on a new Figure object.
#Here, no arguments are passed to add_subplot(), so it creates a single subplot with default settings.

# %%
# Confusing #2
fig = plt.figure()
ax = fig.add_axes([1, 1, 1, 1])
ax.plot(x, y)
plt.show()

#Create a figure and axes using the add_axes() method on a new Figure object. 
#Here, the add_axes() method takes a list of four values that specify the position and 
#size of the axes as a fraction of the figure width and height

# %%
# Easier and more robust going forward (what we're going to use)
fig, ax = plt.subplots()
ax.plot(x, y);

#Create a figure and axes using the subplots() method, which returns both the Figure and Axes objects. 
#Here, we can pass arguments to subplots() to specify the number of rows and columns of subplots to create

# %%
# This is where the object orientated name comes from 
type(fig), type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._subplots.AxesSubplot)

# %% [markdown]
#  ## Anatomy of Matplotlib Figure
#  ![4.1%20matplotlib-anatomy-of-a-plot.png](attachment:4.1%20matplotlib-anatomy-of-a-plot.png)

# %% [markdown]
# ![4.2%20matplotlib-anatomy-of-a-plot-with-code.png](attachment:4.2%20matplotlib-anatomy-of-a-plot-with-code.png)

# %% [markdown]
# ##  Matplotlib example workflow

# %%
# 0. import matplotlib and get it reasy for plotting in Jupyter

# %matplotlib inline
import matplotlib.pyplot as plt

# 1. preapre data
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]

# 2. setup plot
fig, ax = plt.subplots(figsize=(10,10))

#3. Plot data
ax.plot(x,y)

#4. Customize plot
ax.set(title = "Demo Plot",
      xlabel = "x-axis",
      ylabel = "y-axis")

#5. Save or show 

fig.savefig("../Matplotlib Workspace/sample-plot.png")

# %% [markdown]
# ## Making figures with NumPy arrays

# %%
#Creat some data
x = np.linspace(0,10,100)

# %%
x[0:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
# Plot the data and create a line plot

fig , ax = plt.subplots()
ax.plot(x,x**2)

# %%
#use same data and make a scatter plot

fig, ax = plt.subplots()
ax.scatter(x, np.exp(x))

# %%
# another scatter plot 

fig, ax = plt.subplots()
ax.scatter (x, np.sin(x))

# %%
# Make a plot from dictionary 

fruits_price = {
    "apple" : 50,
    "Mango" : 25,
    "Banana" : 5,
    "Pineapple" : 30    
}

fig, ax = plt.subplots()
ax.bar (fruits_price.keys(),fruits_price.values())
ax.set(title = "Fruits Prices in May2023",
       xlabel = "Fruits",
       ylabel = "price");

# %%
fig, ax = plt.subplots()
ax.barh(list(fruits_price.keys()), list(fruits_price.values()));

# %%
#Histograms 

# Make some data from a normal distribution
x = np.random.randn(1000) # pulls data from a normal distribution

fig, ax = plt.subplots()
ax.hist(x);

# %%
x = np.random.random(1000) # random data from random distribution

fig, ax = plt.subplots()
ax.hist(x);

# %%
#SubPlots 

# Option 1: Create multiple subplots
fig, ((ax1,ax2),(ax3,ax4)) = plt.subplots(nrows=2,ncols=2,figsize=(10, 5))
# Plot data to each axis
ax1.plot(x, x/2);
ax2.scatter(np.random.random(10), np.random.random(10));
ax3.bar(fruits_price.keys(), fruits_price.values());
ax4.hist(np.random.randn(1000));

# %%
# Option 2: Create multiple subplots
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(10, 5))

# Index to plot data
ax[0, 0].plot(x, x/2);
ax[0, 1].scatter(np.random.random(10), np.random.random(10));
ax[1, 0].bar(fruits_price.keys(), fruits_price.values());
ax[1, 1].hist(np.random.randn(1000));

# %%
# Plotting data directly with pandas

car_sales = pd.read_csv("car-sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
ts = pd.Series(np.random.randn(1000),
               index = pd.date_range("01/01/2023",periods=1000))

ts
# Out:
# 2023-01-01   -0.310944
# 2023-01-02    0.378438
# 2023-01-03    0.028348
# 2023-01-04   -1.244717
# 2023-01-05    0.596648
#                 ...
# 2025-09-22    0.242587
# 2025-09-23    0.953527
# 2025-09-24    1.868690
# 2025-09-25   -1.269332
# 2025-09-26    0.708999
# Freq: D, Length: 1000, dtype: float64

# %%
# What does cumsum() do?
ts.cumsum()
# Out:
# 2023-01-01   -0.310944
# 2023-01-02    0.067494
# 2023-01-03    0.095843
# 2023-01-04   -1.148874
# 2023-01-05   -0.552226
#                 ...
# 2025-09-22   -8.859827
# 2025-09-23   -7.906301
# 2025-09-24   -6.037611
# 2025-09-25   -7.306942
# 2025-09-26   -6.597943
# Freq: D, Length: 1000, dtype: float64

# %%
ts.cumsum().plot();

# %%
# Remove price column symbols
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', '')
car_sales
# Out:
# C:\Users\srini\AppData\Local\Temp\ipykernel_7196\54845402.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', '')
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
# Remove last two zeros
car_sales["Price"] = car_sales["Price"].str[:-2]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
# Add a date column
car_sales["Sale Date"] = pd.date_range("1/1/2023", periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date
# 0  Toyota  White         150043      4   4000 2023-01-01
# 1   Honda    Red          87899      4   5000 2023-01-02
# 2  Toyota   Blue          32549      3   7000 2023-01-03
# 3     BMW  Black          11179      5  22000 2023-01-04
# 4  Nissan  White         213095      4   3500 2023-01-05
# 5  Toyota  Green          99213      4   4500 2023-01-06
# 6   Honda   Blue          45698      4   7500 2023-01-07
# 7   Honda   Blue          54738      4   7000 2023-01-08
# 8  Toyota  White          60000      4   6250 2023-01-09
# 9  Nissan  White          31600      4   9700 2023-01-10

# %%
# Make total sales column (doesn't work, adds as string)
#car_sales["Total Sales"] = car_sales["Price"].cumsum()

# Oops... want them as int's not string
car_sales["Total Sales"] = car_sales["Price"].astype(int).cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2023-01-01         4000
# 1   Honda    Red          87899      4   5000 2023-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2023-01-03        16000
# 3     BMW  Black          11179      5  22000 2023-01-04        38000
# 4  Nissan  White         213095      4   3500 2023-01-05        41500
# 5  Toyota  Green          99213      4   4500 2023-01-06        46000
# 6   Honda   Blue          45698      4   7500 2023-01-07        53500
# 7   Honda   Blue          54738      4   7000 2023-01-08        60500
# 8  Toyota  White          60000      4   6250 2023-01-09        66750
# 9  Nissan  White          31600      4   9700 2023-01-10        76450

# %%
car_sales.plot(x='Sale Date', y='Total Sales');

# %%
#Scatter


car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter");

# %%
#Bar

x = np.random.rand(10, 4)
x
# Out:
# array([[0.26596417, 0.03894511, 0.80629822, 0.01845483],
#        [0.72482178, 0.58424276, 0.58966535, 0.25469963],
#        [0.05661254, 0.0875598 , 0.39469851, 0.20032183],
#        [0.53523014, 0.65194115, 0.91344185, 0.67032005],
#        [0.87648047, 0.47477164, 0.00597086, 0.7240093 ],
#        [0.50938662, 0.5273132 , 0.53898143, 0.36199326],
#        [0.96833061, 0.35286998, 0.18341339, 0.34546332],
#        [0.10673143, 0.80413891, 0.64967315, 0.26244324],
#        [0.85013295, 0.61977882, 0.46218588, 0.65250429],
#        [0.58820702, 0.85207764, 0.45322299, 0.66428755]])

# %%
df = pd.DataFrame(x, columns=['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0  0.265964  0.038945  0.806298  0.018455
# 1  0.724822  0.584243  0.589665  0.254700
# 2  0.056613  0.087560  0.394699  0.200322
# 3  0.535230  0.651941  0.913442  0.670320
# 4  0.876480  0.474772  0.005971  0.724009
# 5  0.509387  0.527313  0.538981  0.361993
# 6  0.968331  0.352870  0.183413  0.345463
# 7  0.106731  0.804139  0.649673  0.262443
# 8  0.850133  0.619779  0.462186  0.652504
# 9  0.588207  0.852078  0.453223  0.664288

# %%
df.plot.bar();

# %%
# Can do the same thing with 'kind' keyword
df.plot(kind='bar');

# %%
car_sales.plot(x='Make', y='Odometer (KM)', kind='bar');

# %%
#Histograms

car_sales["Odometer (KM)"].plot.hist();

# %%
car_sales["Odometer (KM)"].plot(kind="hist");

# %%
# Default number of bins is 10 
car_sales["Odometer (KM)"].plot.hist(bins=10);

# %%
# Default number of bins is 10 
car_sales["Odometer (KM)"].plot.hist(bins=5);

# %%
# Default number of bins is 10 
car_sales["Odometer (KM)"].plot.hist(bins=20);

# %%
# Let's try with another dataset
heart_disease = pd.read_csv("../Matplotlib Workspace/heart-disease.csv")
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
#create a histogram of age

heart_disease["age"].plot.hist();

# %%
heart_disease["age"].plot.hist(bins=40);

# %%
heart_disease.plot.hist(figsize=(10, 30), subplots=True);

# %% [markdown]
# ## Plotting with pandas using the OO method

# %% [markdown]
# For more complicated plots, you'll want to use the OO method.

# %%
# Perform data analysis on patients over 50

over_50 = heart_disease[ heart_disease["age"] > 50]
over_50
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 3        2   0     2       1
# 4        2   0     2       1
# 5        1   0     1       1
# 6        1   0     2       1
# ..     ...  ..   ...     ...
# 297      1   2     1       0
# 298      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [208 rows x 14 columns]

# %%
#pyplot method
over_50.plot(kind="scatter",
            x = "age",
            y = "chol",
            c = "target",
            figsize = (10,6));

# %%
#oo method
fig, ax = plt.subplots(figsize=(10, 6))
over_50.plot(kind='scatter', 
             x="age", 
             y="chol", 
             c='target', 
             ax=ax);
ax.set_xlim([45, 100]);

# %%
## oo method 

fig, ax = plt.subplots(figsize=(10,6))

#plot the data
scatter = ax.scatter(x=over_50["age"],
                    y=over_50["chol"],
                    c = over_50["target"])

#customize the plot

ax.set(title="Heart Disease and Cholesterol Levels",
       xlabel="Age",
       ylabel="Cholesterol")

#adding the legend

ax.legend(*scatter.legend_elements(), title="Target");

# %%
#What if we wanted a horizontal line going across with the mean of heart_disease["chol"]?

fig, ax = plt.subplots(figsize=(10,6))

#plot the data
scatter = ax.scatter(x=over_50["age"],
                    y=over_50["chol"],
                    c = over_50["target"])

#customize the plot

ax.set(title="Heart Disease and Cholesterol Levels",
       xlabel="Age",
       ylabel="Cholesterol")

#adding the legend

ax.legend(*scatter.legend_elements(), title="Target");

# Add a meanline
ax.axhline(over_50["chol"].mean(),
           linestyle="--");

# %%
#subplot of chol, age, thalach

fig, (ax0,ax1) = plt.subplots(nrows=2,
                             ncols=1,
                             figsize = (10,10));

#add data to ax0
scatter = ax0.scatter(x = over_50["age"],
                     y = over_50["chol"],
                     c = over_50["target"]);

#customize the plot

ax0.set(title="Heart Disease and Cholesterol Levels",
       xlabel="Age",
       ylabel="Cholesterol")

#adding the legend

ax0.legend(*scatter.legend_elements(), title="Target");
# Add a meanline
ax0.axhline(over_50["chol"].mean(),
           linestyle="--");



#add data to ax1
scatter = ax1.scatter(x = over_50["age"],
                     y = over_50["thalach"],
                     c = over_50["target"]);

#customize the plot

ax1.set(title="Heart Disease and Max Heart rate",
       xlabel="age",
       ylabel="thalach")

#adding the legend

ax1.legend(*scatter.legend_elements(), title="Target");
# Add a meanline
ax1.axhline(over_50["thalach"].mean(),
           linestyle="--");

# %% [markdown]
# ## Style

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2023-01-01         4000
# 1   Honda    Red          87899      4   5000 2023-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2023-01-03        16000
# 3     BMW  Black          11179      5  22000 2023-01-04        38000
# 4  Nissan  White         213095      4   3500 2023-01-05        41500
# 5  Toyota  Green          99213      4   4500 2023-01-06        46000
# 6   Honda   Blue          45698      4   7500 2023-01-07        53500
# 7   Honda   Blue          54738      4   7000 2023-01-08        60500
# 8  Toyota  White          60000      4   6250 2023-01-09        66750
# 9  Nissan  White          31600      4   9700 2023-01-10        76450

# %%
car_sales["Price"].dtype
# Out:
# dtype('O')

# %%
# Plot before changing style
car_sales["Price"].astype(int).plot();

# %%
# Change the style... 
plt.style.use('seaborn-whitegrid')

# %%
car_sales["Price"].astype(int).plot();

# %%
plt.style.use('seaborn')
car_sales["Price"].astype(int).plot();

# %%
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter");

# %%
plt.style.use('ggplot')
car_sales["Price"].astype('int').plot.hist();

# %%
# create some date 

x= np.random.randn(10,4)
x
# Out:
# array([[-0.26375432,  0.00819622, -0.06925725,  0.43340118],
#        [ 0.53588985, -2.31923955,  0.40619321,  1.73772745],
#        [ 0.86590377,  0.17600219, -1.23560379, -0.67365183],
#        [-0.66261046,  0.07297271, -1.34043148,  0.46259749],
#        [-1.8836673 , -0.88925982, -0.90283693,  1.10946399],
#        [-1.07858212, -0.81090293, -0.61156204, -0.41312524],
#        [ 0.92009254, -0.73013405, -0.61452228,  0.00961366],
#        [-1.24756053,  3.01861663,  1.36858651, -0.51883353],
#        [ 1.26387477, -2.17718475,  1.48487385, -0.20345441],
#        [ 0.49054085, -0.75785396,  0.76397147, -0.04808764]])

# %%
df = pd.DataFrame(x,columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0 -0.263754  0.008196 -0.069257  0.433401
# 1  0.535890 -2.319240  0.406193  1.737727
# 2  0.865904  0.176002 -1.235604 -0.673652
# 3 -0.662610  0.072973 -1.340431  0.462597
# 4 -1.883667 -0.889260 -0.902837  1.109464
# 5 -1.078582 -0.810903 -0.611562 -0.413125
# 6  0.920093 -0.730134 -0.614522  0.009614
# 7 -1.247561  3.018617  1.368587 -0.518834
# 8  1.263875 -2.177185  1.484874 -0.203454
# 9  0.490541 -0.757854  0.763971 -0.048088

# %%
ax = df.plot(kind="bar");

# %%
#Customize our plot with set() method
ax = df.plot(kind="bar")

#add some labels and a title
ax.set(title = "Random Number Bar Graph from DataFrame", 
       xlabel="Row number", 
       ylabel="Random number")
ax.legend().set_visible(True);

# %%
# Changing the cmap

plt.style.use('seaborn-whitegrid')

# No cmap change
fig, ax = plt.subplots(figsize=(10, 6))
scatter = ax.scatter(over_50["age"], 
                     over_50["chol"], 
                     c=over_50["target"])
ax.set(title="Heart Disease and Cholesterol Levels",
       xlabel="Age",
       ylabel="Cholesterol");
ax.axhline(y=over_50["chol"].mean(), 
           c='b', 
           linestyle='--', 
           label="Average");
ax.legend(*scatter.legend_elements(), title="Target");

# %%
# Change cmap and horizontal line to be a different colour
fig, ax = plt.subplots(figsize=(10, 6))
scatter = ax.scatter(over_50["age"], 
                     over_50["chol"], 
                     c=over_50["target"], 
                     cmap="winter")
ax.set(title="Heart Disease and Cholesterol Levels",
       xlabel="Age",
       ylabel="Cholesterol")
ax.axhline(y=over_50["chol"].mean(), 
           color='r', 
           linestyle='--', 
           label="Average");
ax.legend(*scatter.legend_elements(), title="Target");

# %%
#Changing the xlim & ylim

## Before the change (we've had color updates)

fig, (ax0, ax1) = plt.subplots(nrows=2, ncols=1, sharex=True, figsize=(10, 10))
scatter = ax0.scatter(over_50["age"], 
                      over_50["chol"], 
                      c=over_50["target"],
                      cmap='winter')
ax0.set(title="Heart Disease and Cholesterol Levels",
        ylabel="Cholesterol")

# Setup a mean line
ax0.axhline(y=over_50["chol"].mean(), 
            color='r', 
            linestyle='--', 
            label="Average");
ax0.legend(*scatter.legend_elements(), title="Target")

# Axis 1, 1 (row 1, column 1)
scatter = ax1.scatter(over_50["age"], 
                      over_50["thalach"], 
                      c=over_50["target"],
                      cmap='winter')
ax1.set(title="Heart Disease and Max Heart Rate Levels",
        xlabel="Age",
        ylabel="Max Heart Rate")

# Setup a mean line
ax1.axhline(y=over_50["thalach"].mean(), 
            color='r', 
            linestyle='--', 
            label="Average");
ax1.legend(*scatter.legend_elements(), title="Target")

# Title the figure
fig.suptitle('Heart Disease Analysis', fontsize=16, fontweight='bold');

# %%
## After adding in different x & y limitations

fig, (ax0, ax1) = plt.subplots(nrows=2, ncols=1, sharex=True, figsize=(10, 10))
scatter = ax0.scatter(over_50["age"], 
                      over_50["chol"], 
                      c=over_50["target"],
                      cmap='winter')
ax0.set(title="Heart Disease and Cholesterol Levels",
        ylabel="Cholesterol")

# Set the x axis
ax0.set_xlim([50, 80])

# Setup a mean line
ax0.axhline(y=over_50["chol"].mean(), 
            color='r', 
            linestyle='--', 
            label="Average");
ax0.legend(*scatter.legend_elements(), title="Target")

# Axis 1, 1 (row 1, column 1)
scatter = ax1.scatter(over_50["age"], 
                      over_50["thalach"], 
                      c=over_50["target"],
                      cmap='winter')
ax1.set(title="Heart Disease and Max Heart Rate Levels",
        xlabel="Age",
        ylabel="Max Heart Rate")

# Set the y axis
ax1.set_ylim([60, 200])

# Setup a mean line
ax1.axhline(y=over_50["thalach"].mean(), 
            color='r', 
            linestyle='--', 
            label="Average");
ax1.legend(*scatter.legend_elements(), title="Target")

# Title the figure
fig.suptitle('Heart Disease Analysis', fontsize=16, fontweight='bold');

# %% [markdown]
# ## Saving plots

# %% [markdown]
# Saving plots to images using figsave()
#
# If you're doing something like this often, to save writing excess code, you might put it into a function.
#
# A function which follows the Matplotlib workflow.

# %%
# Save the file
fig.savefig("../Matplotlib Workspace/heart-disease-analysis.png")
